# %%
N, M = map(int,input().split()) # STDIN numbers into two var ej: 7 21

for i in range(1, N, 2): # This print the above part
    print(('.|.'*i).center(M, '-'))
    
print('WELCOME'.center(M, '-'))

for i in range(N-2, 0, -2): # This print the below part
    print(('.|.'*i).center(M, '-'))
# Out:
# 25 75
# ------------------------------------.|.------------------------------------
# ---------------------------------.|..|..|.---------------------------------
# ------------------------------.|..|..|..|..|.------------------------------
# ---------------------------.|..|..|..|..|..|..|.---------------------------
# ------------------------.|..|..|..|..|..|..|..|..|.------------------------
# ---------------------.|..|..|..|..|..|..|..|..|..|..|.---------------------
# ------------------.|..|..|..|..|..|..|..|..|..|..|..|..|.------------------
# ---------------.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.---------------
# ------------.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.------------
# ---------.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.---------
# ------.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.------
# ---.|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|..|.---
# ...
